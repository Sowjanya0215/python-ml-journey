# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sm

# %%
#LOAD DATASET
df=pd.read_csv(r'C:\Users\dasar\OneDrive\Desktop\project\employe.csv')
df
# Out:
#     Age  Salary    Position  Experience
# 0  22.0   25000          HR         1.0
# 1  25.0   30000          IT         NaN
# 2  30.0   45000       Sales         5.0
# 3  35.0   50000     Finance         7.0
# 4  28.0   35000   Marketing         3.0
# 5   NaN   65000          IT        10.0
# 6  32.0   42000  Operations         NaN

# %%
df.head()
# Out:
#     Age  Salary   Position  Experience
# 0  22.0   25000         HR         1.0
# 1  25.0   30000         IT         NaN
# 2  30.0   45000      Sales         5.0
# 3  35.0   50000    Finance         7.0
# 4  28.0   35000  Marketing         3.0

# %%
#DATA INFORMATION
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Age         6 non-null      float64
#  1   Salary      7 non-null      int64
#  2   Position    7 non-null      object
#  3   Experience  5 non-null      float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 352.0+ bytes

# %%
#CHEKING MISSING VALUES
df.isnull().sum()
# Out:
# Age           1
# Salary        0
# Position      0
# Experience    2
# dtype: int64

# %%
#DATA CLEANING
df.drop_duplicates()
# Out:
#     Age  Salary    Position  Experience
# 0  22.0   25000          HR         1.0
# 1  25.0   30000          IT         NaN
# 2  30.0   45000       Sales         5.0
# 3  35.0   50000     Finance         7.0
# 4  28.0   35000   Marketing         3.0
# 5   NaN   65000          IT        10.0
# 6  32.0   42000  Operations         NaN

# %%
df.fillna(df.mean(numeric_only=True))
# Out:
#          Age  Salary    Position  Experience
# 0  22.000000   25000          HR         1.0
# 1  25.000000   30000          IT         5.2
# 2  30.000000   45000       Sales         5.0
# 3  35.000000   50000     Finance         7.0
# 4  28.000000   35000   Marketing         3.0
# 5  28.666667   65000          IT        10.0
# 6  32.000000   42000  Operations         5.2

# %%
df["salary_in_lakhs"] = df["Salary"] / 100000
df["salary_in_lakhs"]
# Out:
# 0    0.25
# 1    0.30
# 2    0.45
# 3    0.50
# 4    0.35
# 5    0.65
# 6    0.42
# Name: salary_in_lakhs, dtype: float64

# %%
#VISUALISATION

# %%
sm.histplot(df["Salary"])
plt.show()

# %%
sm.scatterplot(x="Salary",y="Experience",data=df)
plt.show()

# %%
sm.barplot(x="Salary",y="Experience",data=df)
plt.show()

# %%
sm.heatmap(df.corr(numeric_only=True), annot=True)
plt.show()
