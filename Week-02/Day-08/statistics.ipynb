# %%
import pandas as pd

# %%
data=[12,34,5,6,30,30,80]
df=pd.Series(data)
print("Mean:",df.mean())
# Out:
# Mean: 28.142857142857142

# %%
print("mode",df.mode())
# Out:
# mode 0    30
# dtype: int64

# %%
print("median:",df.median())
# Out:
# median: 30.0

# %%
print("standard deviation:",df.std())
# Out:
# standard deviation: 25.874237968995153

# %%
print("variance",df.var())
# Out:
# variance 669.4761904761905

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.histplot(df)
plt.title("Data distribution")
plt.show()

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 sns.heatmap(df.corr(numeric_only=True), annot=True)
#       2 plt.show()
#
# TypeError: Series.corr() got an unexpected keyword argument 'numeric_only'

# %%
print(type(df))
# Out:
# <class 'pandas.core.series.Series'>
